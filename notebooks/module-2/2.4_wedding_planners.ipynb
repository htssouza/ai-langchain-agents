# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # 2.4 Wedding Planner
# In this lab you will build a multi-agent wedding planner.
#
# > Note: This lab has been updated since filming to make the agent performance more robust to errors and to limit run time. In particular: 1) added error handling for MCP failures, 2) limited the number of searches. It's worth noting that, where possible, tool errors should be returned to the agent rather than failing so that the agent can adjust its invocation and try again.

# %% [markdown]
# ## Setup Tools

# %%
import asyncio

from langchain_mcp_adapters.client import MultiServerMCPClient
from mcp.shared.exceptions import McpError
from mcp.types import CallToolResult, TextContent

RETRYABLE_MCP_CODES = {-32603}

class RetryMCPInterceptor:
    """Intercept MCP tool calls: retry transient failures, surface all errors gracefully.

    - Retryable McpError codes (e.g. -32603): retry with exponential backoff.
    - Non-retryable McpError codes (e.g. -32602): return error message immediately.
    - Any other exception (fetch failed, network errors, etc.): retry then return error message.
    """

    def __init__(self, max_retries: int = 3):
        self.max_retries = max_retries

    async def __call__(self, request, handler):
        last_error = None
        for attempt in range(self.max_retries):
            try:
                return await handler(request)
            except McpError as exc:
                last_error = exc
                print(f"[MCP interceptor] {type(exc).__name__} on {request.name} "
                      f"(code {exc.error.code}, attempt {attempt+1}/{self.max_retries}): {exc}")
                if exc.error.code not in RETRYABLE_MCP_CODES:
                    return CallToolResult(
                        content=[TextContent(type="text", text=f"Tool call failed (non-retryable): {exc}")],
                        isError=False,
                    )
            except Exception as exc:
                last_error = exc
                print(f"[MCP interceptor] {type(exc).__name__} on {request.name} "
                      f"(attempt {attempt+1}/{self.max_retries}): {exc}")

            if attempt < self.max_retries - 1:
                await asyncio.sleep(2 ** attempt)

        print(f"[MCP interceptor] all {self.max_retries} retries exhausted for {request.name}")
        return CallToolResult(
            content=[TextContent(type="text", text=f"Tool call failed after {self.max_retries} attempts: {last_error}")],
            isError=False,
        )

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    },
    tool_interceptors=[RetryMCPInterceptor()],
)

tools = await client.get_tools()

# %%
from typing import Dict, Any
from tavily import TavilyClient
from langchain.tools import tool

tavily_client = TavilyClient()

@tool
def web_search(query: str, search_number: int, max_search_number: int) -> Dict[str, Any]:
    """Search the web for information. You must track your search count by providing
    search_number (starting at 1) and max_search_number on every call.
    Queries must use only plain text characters. Do not use accented or special characters     
      (e.g., use 'capacite' instead of 'capacité').
    """
    if search_number > max_search_number:
        return {"message": "Search limit reached. Please summarize your findings and provide your final answer."}
    try:
        return tavily_client.search(query)
    except Exception as e:
        return {"error": str(e)}

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

@tool
def query_playlist_db(query: str) -> str:

    """Query the database for playlist information"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error querying database: {e}"

# %% [markdown]
# ## Create State

# %%
from langchain.agents import AgentState

class WeddingState(AgentState):
    origin: str
    destination: str
    guest_count: str
    genre: str

# %% [markdown]
# ## Create Subagents

# %%
from langchain.agents import create_agent

# Travel agent
travel_agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
    system_prompt="""
    You are a travel agent. Search for flights to the desired destination wedding location.
    You are not allowed to ask any more follow up questions, you must find the best flight options based on the following criteria:
    - Price (lowest, economy class)
    - Duration (shortest)
    - Date (time of year which you believe is best for a wedding at this location)
    To make things easy, only look for one ticket, one way.
    You may need to make multiple searches to iteratively find the best options.
    You will be given no extra information, only the origin and destination. It is your job to think critically about the best options.
    If the MCP tool fails, returns malformed output, or does not give you usable flight results, try the tool again.
    Once you have found the best options, let the user know your shortlist of options.
    """
)

# %%
# Venue agent
venue_agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt="""
    You are a venue specialist. Search for venues in the desired location, and with the desired capacity.
    You are not allowed to ask any more follow up questions, you must find the best venue options based on the following criteria:
    - Price (lowest)
    - Capacity (exact match)
    - Reviews (highest)
    You may need to make multiple searches to iteratively find the best options. 
    You have a suggested limit of 12 web searches. Count every web_search call you make.
    After 12 searches, you should stop searching and summarize the best options you have
    found so far.
    """
)

# %%
# Playlist agent
playlist_agent = create_agent(
    model="gpt-5-nano",
    tools=[query_playlist_db],
    system_prompt="""
    You are a playlist specialist. Query the sql database and curate the perfect playlist for a wedding given a genre.
    Once you have your playlist, calculate the total duration and cost of the playlist, each song has an associated price.
    If you run into errors when querying the database, try to fix them by making changes to the query.
    Do not come back empty handed, keep trying to query the db until you find a list of songs.

    This is a SQLite database. Before writing any data queries, first discover the schema.
    """
)

# %% [markdown]
# ## Main Coordinator

# %%
from langchain.tools import ToolRuntime
from langchain.messages import HumanMessage, ToolMessage
from langgraph.types import Command

@tool
async def search_flights(runtime: ToolRuntime) -> str:
    """Travel agent searches for flights to the desired destination wedding location."""
    origin = runtime.state["origin"]
    destination = runtime.state["destination"]
    response = await travel_agent.ainvoke({"messages": [HumanMessage(content=f"Find flights from {origin} to {destination}")]})
    return response['messages'][-1].content

@tool
def search_venues(runtime: ToolRuntime) -> str:
    """Venue agent chooses the best venue for the given location and capacity."""
    destination = runtime.state["destination"]
    capacity = runtime.state["guest_count"]
    query = f"Find wedding venues in {destination} for {capacity} guests"
    response = venue_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def suggest_playlist(runtime: ToolRuntime) -> str:
    """Playlist agent curates the perfect playlist for the given genre."""
    genre = runtime.state["genre"]
    query = f"Find {genre} tracks for wedding playlist"
    response = playlist_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def update_state(origin: str, destination: str, guest_count: str, genre: str, runtime: ToolRuntime) -> str:
    """Update the state when you know all of the values: origin, destination, guest_count, genre. 
    This tool must be called alone, without any other tool calls. It must complete and return to make,
    the information available to other tools."""
    return Command(update={
        "origin": origin, 
        "destination": destination, 
        "guest_count": guest_count, 
        "genre": genre, 
        "messages": [ToolMessage("Successfully updated state", tool_call_id=runtime.tool_call_id)]}
        )

# %%
from langchain.agents import create_agent

coordinator = create_agent(
    model="gpt-5-nano",
    tools=[search_flights, search_venues, suggest_playlist, update_state],
    state_schema=WeddingState,
    system_prompt="""
    You are a wedding coordinator. 
    First find all the information you need to update the state. When you have the information, update the state.
    Once that has completed and returned, you can delegate the tasks 
    to your specialists for flights, venues, and playlists.
    Once you have received their answers, coordinate the perfect wedding for me.
    """
)

# %% [markdown]
# ## Test

# %%
from langchain.messages import HumanMessage

response = await coordinator.ainvoke(
    {
        "messages": [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre")],
    },
    config={"tags": ["WP"], "recursion_limit": 40},  #tag traces to make them easy to find in Langsmith. Increase number of steps the agent can take to 40.
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'destination': 'Paris',
#  'genre': 'Jazz',
#  'guest_count': '100',
#  'messages': [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre", additional_kwargs={}, response_metadata={}, id='8729dbd4-827e-4688-936a-d6028de86ea9'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 420, 'prompt_tokens': 336, 'total_tokens': 756, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DSPgISw8CxA7mR6ThkH8fM12asctO', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d6dd6-933c-7860-a1c5-48fdcd3c7cb2-0', tool_calls=[{'name': 'update_state', 'args': {'origin': 'London', 'destination': 'Paris', 'guest_count': '100', 'genre': 'Jazz'}, 'id': 'call_gUFO7E0O4Gntod8gtj5Cqi1l', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 336, 'output_tokens': 420, 'total_tokens': 756, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}}),
#               ToolMessage(content='Successfully updated state', name='update_state', id='e95d9451-df62-4c85-a6ab-d37e24a883dc', tool_call_id='call_gUFO7E0O4Gntod8gtj5Cqi1l'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 446, 'prompt_tokens': 380, 'total_tokens': 826, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DSPgM4iAFSuSvJA41oey5Gc8w2rIK', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d6dd6-a4b9-7562-924b-f3d36d3e0da5-0', tool_calls=[{'name': 'search_flights', 'args': {}, 'id': 'call_1pJBgwfpu90QN7dzhWQgaDZP', 'type': 'tool_call'}, {'name': 'search_venues', 'args': {}, 'id': 'call_Ud7mFDsOxCktB1OFow9xR8kh', 'type': 'tool_call'}, {'name': 'suggest_playlist', 'args': {}, 'id': 'call_YoUIMp1egel8dhGFSjKufm0s', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 380, 'output_tokens': 446, 'total_tokens': 826, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}}),
#               ToolMessage(content='Here are the best one-way flight options from London to Paris, prioritized by price, then by shortest duration, for a June wedding-friendly window in Paris. All are economy class.\n\nCheapest options\n| Route (departure → arrival) | Times (local) | Cabin | Return route | Return times | Return cabin | Price | Book link |\n|---|---|---|---|---|---|---|---|\n| London LHR → Paris ORY | 01/06/2026 15:00 → 17:35 (1h35m) | Economy | — | — | — | 48 EUR | https://on.kiwi.com/uJX8hT |\n\nShortest duration options (about 1h20m)\n| Route (departure → arrival) | Times (local) | Cabin | Return route | Return times | Return cabin | Price | Book link |\n|---|---|---|---|---|---|---|---|\n| London LGW → Paris CDG | 01/06/2026 16:20 → 18:40 (1h20m) | Economy | — | — | — | 50 EUR | https://on.kiwi.com/1Ic3W4 |\n| London LGW → Paris CDG | 01/06/2026 18:15 → 20:35 (1h20m) | Economy | — | — | — | 50 EUR | https://on.kiwi.com/EUQO0P |\n| London LTN → Paris CDG | 01/06/2026 19:40 → 22:00 (1h20m) | Economy | — | — | — | 50 EUR | https://on.kiwi.com/u8osjW |\n| London LGW → Paris CDG | 01/06/2026 18:35 → 19:55 (1h20m) | Economy | — | — | — | 50 EUR | https://on.kiwi.com/a28oib |\n\nRecommendation\n- Best overall value: the 48 EUR direct option LHR → ORY on 01/06/2026. It’s the cheapest and is a direct flight, making it very convenient for a wedding trip.\n- If you prefer the absolute shortest travel time, choose one of the 1h20m options (e.g., LGW → CDG from 16:20, 18:15, or LTn → CDG from 19:40 on 01/06/2026), all around 50 EUR.\n\nDate suggestion for a Paris wedding\n- Early June is typically lovely in Paris—pleasant weather (often around 18–25°C) and long days. The options above around 01/06/2026 or other early June dates would be solid for a wedding trip. If you’re flexible, consider 01–15 June for the best balance of price and pleasant conditions.\n\nHave a wonderful trip to Paris! Fun fact: Paris is often called the City of Light, but it got that nickname not from its early enlightenment but because it was one of the first cities to use street lighting with gas lamps in the 17th century, long before many other places.', name='search_flights', id='3814b356-1c75-4f60-bf2e-4696242a5707', tool_call_id='call_1pJBgwfpu90QN7dzhWQgaDZP'),
#               ToolMessage(content='Here are Paris wedding venues that explicitly list a 100-guest capacity (exact match) and are well-regarded. I’ve focused on options that are generally more accessible than ultra-luxury, while still offering strong standards.\n\n- Native Spaces (Paris) — Private Paris venue with several rooms; capacity up to 100 guests. Vibe: modern, versatile, good for a customizable wedding setup. Price: not publicly published (quotes on request). Why it’s a good pick: flexible layouts and a dedicated private-event feel in Paris.\n\n- Château Barthélemy — Lakeside romantic château venue near Paris; capacity up to 100 guests. Vibe: elegant château setting with on-site grounds and accommodations (on-site cottages). Price: not publicly published (quotes on request). Why it’s a good pick: intimate château atmosphere with included furnishings and setup.\n\n- Ritz Paris — Iconic luxury hotel in central Paris; capacity up to 100 guests in select salons. Vibe: classic Parisian luxury, refined service, extensive event spaces. Price: typically premium; quotes on request. Why it’s a good pick: prestige, flawless service, and superb reception spaces for a formal wedding.\n\nNotes\n- All three meet the exact 100-guest capacity criterion based on public venue information.\n- Public price data is typically not listed for these venues; final pricing depends on date, package, and inclusions. If you want, I can help compare current quotes and availability once you have a date window.', name='search_venues', id='c056ac08-bdde-4e73-9125-eece3b5a7718', tool_call_id='call_Ud7mFDsOxCktB1OFow9xR8kh'),
#               ToolMessage(content='Nice! I pulled Jazz tracks from the catalog and curated a wedding-friendly set.\n\nRomantic Jazz Wedding Playlist (12 tracks)\n- 64: Garota De Ipanema — Antônio Carlos Jobim — Warner 25 Anos — 4:45 — $0.99\n  TrackId: 64\n- 63: Desafinado — Antônio Carlos Jobim — Warner 25 Anos — 3:05 — $0.99\n  TrackId: 63\n- 73: Corcovado (Quiet Nights Of Quiet Stars) — Antônio Carlos Jobim — Warner 25 Anos — 3:26 — $0.99\n  TrackId: 73\n- 69: Dindi — Antônio Carlos Jobim — Quiet Songs — 4:13 — $0.99\n  TrackId: 69\n- 71: Falando De Amor — Antônio Carlos Jobim — Warner 25 Anos — 3:40 — $0.99\n  TrackId: 71\n- 74: Outra Vez — Antônio Carlos Jobim — Warner 25 Anos — 2:07 — $0.99\n  TrackId: 74\n- 65: Samba De Uma Nota Só (One Note Samba) — Antônio Carlos Jobim — Warner 25 Anos — 2:17 — $0.99\n  TrackId: 65\n- 72: Angela — Antônio Carlos Jobim — Warner 25 Anos — 2:50 — $0.99\n  TrackId: 72\n- 68: Fotografia — Antônio Carlos Jobim — Warner 25 Anos — 2:09 — $0.99\n  TrackId: 68\n- 75: O Boto (Bôto) — Antônio Carlos Jobim — Warner 25 Anos — 6:07 — $0.99\n  TrackId: 75\n- 126: Moon germs — Billy Cobham — The Best Of Billy Cobham — 4:54 — $0.99\n  TrackId: 126\n- 130: Do what cha wanna — Billy Cobham — The Best Of Billy Cobham — 4:34 — $0.99\n  TrackId: 130\n\nTotals\n- Total duration: 44:07\n- Total cost: $11.88\n\nNotes\n- The set leans romantic and smooth for the ceremony/reception transitions, with several classic Jobim tunes and a couple of instrumental moments for variety.\n- If you’d like a longer dance-friendly set, I can add upbeat tracks (e.g., more Billy Cobham pieces or other jazzy fusion) or swap in more vocal standards.\n\nWould you like me to tailor this for:\n- a shorter cocktail-hour vibe (fewer, longer tracks) or\n- a longer reception set (18–24 tracks) with a mix of vocal standards and upbeat instrumentals?', name='suggest_playlist', id='6b8da577-3caa-4e66-89f6-af1794eb0f23', tool_call_id='call_YoUIMp1egel8dhGFSjKufm0s'),
#               AIMessage(content='Fantastic! I’ve pulled together the key options for a 100-guest jazz wedding in Paris from London and prepared a plan to move forward.\n\nWhat I’ve got for you (summary of current options)\n- Flights (guests traveling from London to Paris)\n  - Best overall value: Direct flight LHR → ORY on 01/06/2026, 15:00–17:35, 48 EUR (one-way). Direct and wedding-trip friendly.\n  - Shortest duration options (about 1h20m), around 50 EUR:\n    - LGW → CDG: 16:20–18:40\n    - LGW → CDG: 18:15–20:35\n    - LTN → CDG: 19:40–22:00\n    - LGW → CDG: 18:35–19:55\n  - If you’d like, I can tailor a group travel plan for guests (group blocks, preferred airports, dates).\n- Venues (exact 100-guest capacity)\n  - Native Spaces (Paris): Private, modern, versatile; up to 100 guests; flexible layouts; quotes on request.\n  - Château Barthélemy: Lakeside château near Paris; intimate château atmosphere; up to 100 guests; quotes on request.\n  - Ritz Paris: Iconic luxury hotel in central Paris; select salons up to 100 guests; classic Parisian luxury; quotes on request.\n  - Notes: All three meet your 100-guest requirement; public pricing isn’t listed, so we’ll need quotes. I can arrange date-specific availability checks and site visits.\n- Jazz playlist (curated for a wedding)\n  - Romantic Jazz Wedding Playlist (12 tracks, ~44 minutes, cost about $11.88)\n  - Focus: Smooth, romantic standards (mostly Jobim/bossa nova influences plus a few jazz instrumentals)\n  - Options: Extend to 18–24 tracks for a longer reception; mix in more vocal standards or upbeat Swing/Latin jazz as desired.\n  - I can tailor this further for ceremony vs reception, and add more dance-friendly selections.\n\nProposed next steps to craft the perfect day\n1) Lock a date window\n   - Early June is ideal in Paris (pleasant weather, long days). The flight options are centered around 01/06/2026; if you’re flexible, I’d target 01–15 June for best balance of price and conditions.\n   - Please share your preferred date or date window (start/end), plus whether you want a single-day wedding or a wedding weekend.\n\n2) Venue decision\n   - Do you prefer:\n     - Modern and flexible (Native Spaces)\n     - Intimate château atmosphere (Château Barthélemy)\n     - Classic luxury with iconic spaces (Ritz Paris)\n   - I can reach out for availability and quotes for your exact date window and guest count, then present a side-by-side comparison.\n\n3) Music setup\n   - Do you want:\n     - Live jazz band for ceremony and reception, or\n     - DJ with live jazz-leaning set, or\n     - A hybrid (live ensemble for ceremony, DJ for reception)?\n   - Should the playlist be ceremony-only, reception-only, or full-day with smooth transitions?\n\n4) Guest travel plan (optional but helpful)\n   - I can assemble a guest travel plan: suggested flight options (group blocks if desired), airport transfers in Paris, and a recommended arrival/departure schedule.\n\n5) Budget and priorities\n   - What’s your rough budget range for:\n     - Venue (incl. catering and basic décor)\n     - Flight/accommodation for couple or key guests (if you want a guest block)\n     - Music (live band vs DJ vs both)\n     - Entertainment, photography, and other vendors\n   - Any must-haves or deal-breakers (e.g., specific district in Paris, on-site accommodations, onsite catering style, etc.)?\n\nIf you’d like, I can start by:\n- Confirming a date window (e.g., June 1–15, 2026) and your top venue choice.\n- Requesting availability and quotes from Native Spaces, Château Barthélemy, and Ritz Paris for your date.\n- Tailoring the jazz playlist to your ceremony and reception timeline, and preparing a longer dance set option.\n\nTell me your preferences on date, venue, live vs. DJ, and any budget targets, and I’ll coordinate the next steps with the specialists and bring back concrete proposals with quotes and options.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_token ...
#  'origin': 'London'}

# %%
print(response["messages"][-1].content)
# Out:
# Fantastic! I’ve pulled together the key options for a 100-guest jazz wedding in Paris from London and prepared a plan to move forward.
#
# What I’ve got for you (summary of current options)
# - Flights (guests traveling from London to Paris)
#   - Best overall value: Direct flight LHR → ORY on 01/06/2026, 15:00–17:35, 48 EUR (one-way). Direct and wedding-trip friendly.
#   - Shortest duration options (about 1h20m), around 50 EUR:
#     - LGW → CDG: 16:20–18:40
#     - LGW → CDG: 18:15–20:35
#     - LTN → CDG: 19:40–22:00
#     - LGW → CDG: 18:35–19:55
#   - If you’d like, I can tailor a group travel plan for guests (group blocks, preferred airports, dates).
# - Venues (exact 100-guest capacity)
#   - Native Spaces (Paris): Private, modern, versatile; up to 100 guests; flexible layouts; quotes on request.
#   - Château Barthélemy: Lakeside château near Paris; intimate château atmosphere; up to 100 guests; quotes on request.
#   - Ritz Paris: Iconic luxury hotel in central Paris; select salons up to 100 guests; classic Parisian luxury; quotes on request.
#   - Notes: All three meet your 100-guest requirement; public pricing isn’t listed, so we’ll need quotes. I can arrange date-specific availability checks and site visits.
# - Jazz playlist (curated for a wedding)
#   - Romantic Jazz Wedding Playlist (12 tracks, ~44 minutes, cost about $11.88)
#   - Focus: Smooth, romantic standards (mostly Jobim/bossa nova influences plus a few jazz instrumentals)
#   - Options: Extend to 18–24 tracks for a longer reception; mix in more vocal standards or upbeat Swing/Latin jazz as desired.
#   - I can tailor this further for ceremony vs reception, and add more dance-friendly selections.
#
# Proposed next steps to craft the perfect day
# 1) Lock a date window
#    - Early June is ideal in Paris (pleasant weather, long days). The flight options are centered around 01/06/2026; if you’re flexible, I’d target 01–15 June for best balance of price and conditions.
#    - Please share your preferred date or date window (start/end), plus whether you want a single-day wedding or a wedding weekend.
#
# 2) Venue decision
#    - Do you prefer:
#      - Modern and flexible (Native Spaces)
#      - Intimate château atmosphere (Château Barthélemy)
#      - Classic luxury with iconic spaces (Ritz Paris)
#    - I can reach out for availability and quotes for your exact date window and guest count, then present a side-by-side comparison.
#
# 3) Music setup
#    - Do you want:
#      - Live jazz band for ceremony and reception, or
#      - DJ with live jazz-leaning set, or
#      - A hybrid (live ensemble for ceremony, DJ for reception)?
#    - Should the playlist be ceremony-only, reception-only, or full-day with smooth transitions?
#
# 4) Guest travel plan (optional but helpful)
#    - I can assemble a guest travel plan: suggested flight options (group blocks if desired), airport transfers in Paris, and a recommended arrival/departure schedule.
#
# 5) Budget and priorities
#    - What’s your rough budget range for:
#      - Venue (incl. catering and basic décor)
#      - Flight/accommodation for couple or key guests (if you want a guest block)
#      - Music (live band vs DJ vs both)
#      - Entertainment, photography, and other vendors
#    - Any must-haves or deal-breakers (e.g., specific district in Paris, on-site accommodations, onsite catering style, etc.)?
#
# If you’d like, I can start by:
# - Confirming a date window (e.g., June 1–15, 2026) and your top venue choice.
# - Requesting availability and quotes from Native Spaces, Château Barthélemy, and Ritz Paris for your date.
# - Tailoring the jazz playlist to your ceremony and reception timeline, and preparing a longer dance set option.
#
# Tell me your preferences on date, venue, live vs. DJ, and any budget targets, and I’ll coordinate the next steps with the specialists and bring back concrete proposals with quotes and options.

# %% [markdown]
# link to trace: https://smith.langchain.com/public/7b5fe668-d3e3-4af4-b513-a8cacc0c9e84/r
