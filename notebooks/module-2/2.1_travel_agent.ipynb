# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='a70a6c14-e3d0-4c2e-99d2-c76a18689a0d'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1097, 'prompt_tokens': 1229, 'total_tokens': 2326, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1024, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DSO88ChQdOpU4k904LeP22xnNQjeu', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d6d7b-967a-7610-9249-0e76155ddae9-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '31/03/2027', 'departureDateFlexRange': 0, 'passengers': {'adults': 1}, 'cabinClass': 'M', 'sort': 'price', 'curr': 'USD', 'locale': 'en'}, 'id': 'call_P5cKCgsTtVuKenIrycFOJY3x', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1229, 'output_tokens': 1097, 'total_tokens': 2326, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1024}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2027-03-31T07:50:00.000Z",\n      "local": "2027-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2027-04-01T06:05:00.000Z",\n      "local": "2027-04-01T15:05:00.000"\n    },\n    "totalDurationInSeconds": 80100,\n    "durationInSeconds": 80100,\n    "price": 647,\n    "deepLink": "https://on.kiwi.com/r51ao3",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2027-03-31T21:25:00.000Z",\n          "local": "2027-04-01T05:25:00.000"\n        },\n        "departure": {\n          "utc": "2027-04-01T02:40:00.000Z",\n          "local": "2027-04-01T10:40:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2027-03-31T19:40:00.000Z",\n      "local": "2027-03-31T12:40:00.000"\n    },\n    "arrival": {\n      "utc": "2027-04-02T03:40:00.000Z",\n      "local": "2027-04-02T12:40:00.000"\n    },\n    "totalDurationInSeconds": 115200,\n    "durationInSeconds": 115200,\n    "price": 914,\n    "deepLink": "https://on.kiwi.com/iDBH4y",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "ICN",\n        "city": "Seoul",\n        "cityCode": "SEL",\n        "arrival": {\n          "utc": "2027-04-01T08:20:00.000Z",\n          "local": "2027-04-01T17:20:00.000"\n        },\n        "departure": {\n          "utc": "2027-04-02T01:10:00.000Z",\n          "local": "2027-04-02T10:10:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2027-03-31T19:40:00.000Z",\n      "local": "2027-03-31T12:40:00.000"\n    },\n    "arrival": {\n      "utc": "2027-04-02T06:25:00.000Z",\n      "local": "2027-04-02T15:25:00.000"\n    },\n    "totalDurationInSeconds": 125100,\n    "durationInSeconds": 125100,\n    "price": 914,\n    "deepLink": "https://on.kiwi.com/aAvrAo",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "ICN",\n        "city": "Seoul",\n        "cityCode": "SEL",\n        "arrival": {\n          "utc": "2027-04-01T08:20:00.000Z",\n          "local": "2027-04-01T17:20:00.000"\n        },\n        "departure": {\n          "utc": "2027-04-02T04:00:00.000Z",\n          "local": "2027-04-02T13:00:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "HND",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2027-03-31T19:40:00.000Z",\n      "local": "2027-03-31T12:40:00.000"\n    },\n    "arrival": {\n      "utc": "2027-04-02T16:20:00.000Z",\n      "local": "2027-04-03T01:20:00.000"\n    },\n    "totalDurationInSeconds": 160800,\n    "durationInSeconds": 160800,\n    "price": 973,\n    "deepLink": "https://on.kiwi.com/xewlXi",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "ICN",\n        "city": "Seoul",\n        "cityCode": "SEL",\n        "arrival": {\n          "utc": "2027-04-01T08:20:00.000Z",\n          "local": "2027-04-01T17:20:00.000"\n        },\n        "departure": {\n          "utc": "2027-04-02T01:30:00.000Z",\n          "local": "2027-04-02T10:30:00.000"\n        }\n      },\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2027-04-02T04:10:00.000Z",\n          "local": "2027-04-02T12:10:00.000"\n        },\n        "departure": {\n          "utc": "2027-04-02T07:20:00.000Z",\n          "local": "2027-04-02T15:20:00.000"\n        }\n      },\n      {\n        "at": "HKG",\n        "city": "Hong Kong",\n        "cityCode": "HKG",\n        "arrival": {\n      ...
#               AIMessage(content='Direct flights from San Francisco (SFO) to Tokyo on March 31st are not available in the current search.\n\nClosest options (one-stop itineraries)\n\n- Cheapest option\n  | Route | Dates & Duration | Cabin | Price (USD) | Book |\n  | SFO → NRT (via TPE) | 03/31 00:50 → 04/01 15:05 (22h 15m) | Economy | 647 | https://on.kiwi.com/r51ao3 |\n\n- Other notable options\n  | Route | Dates & Duration | Cabin | Price (USD) | Book |\n  | SFO → NRT (via ICN) | 03/31 12:40 → 04/02 12:40 (32h 0m) | Economy | 914 | https://on.kiwi.com/iDBH4y |\n  | SFO → NRT (via ICN) | 03/31 12:40 → 04/02 15:25 (34h 45m) | Economy | 914 | https://on.kiwi.com/aAvrAo |\n\nRecommendation: If you’re flexible on the date or open to 1-stop itineraries, the cheapest option is the SFO → NRT via Taipei (TPE) at 647 USD. The ICN-stop options at 914 USD are solid alternatives if you prefer different layover locations.\n\nHave a wonderful trip to Tokyo! Fun fact: Tokyo is home to the world’s busiest pedestrian crossing at Shibuya Crossing, where hundreds of people cross from multiple directions with lights turning in synchronized waves.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10846, 'prompt_tokens': 5323, 'total_tokens': 16169, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 10496, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DSO8Kheu0y0T6fsFo5WQiWJJVhyaq', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6d7b-c733-7622-bc56-e71a5fa7ec95-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 5323, 'output_tokens': 10846, 'total_tokens': 16169, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 10496}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Direct flights from San Francisco (SFO) to Tokyo on March 31st are not available in the current search.
#
# Closest options (one-stop itineraries)
#
# - Cheapest option
#   | Route | Dates & Duration | Cabin | Price (USD) | Book |
#   | SFO → NRT (via TPE) | 03/31 00:50 → 04/01 15:05 (22h 15m) | Economy | 647 | https://on.kiwi.com/r51ao3 |
#
# - Other notable options
#   | Route | Dates & Duration | Cabin | Price (USD) | Book |
#   | SFO → NRT (via ICN) | 03/31 12:40 → 04/02 12:40 (32h 0m) | Economy | 914 | https://on.kiwi.com/iDBH4y |
#   | SFO → NRT (via ICN) | 03/31 12:40 → 04/02 15:25 (34h 45m) | Economy | 914 | https://on.kiwi.com/aAvrAo |
#
# Recommendation: If you’re flexible on the date or open to 1-stop itineraries, the cheapest option is the SFO → NRT via Taipei (TPE) at 647 USD. The ICN-stop options at 914 USD are solid alternatives if you prefer different layover locations.
#
# Have a wonderful trip to Tokyo! Fun fact: Tokyo is home to the world’s busiest pedestrian crossing at Shibuya Crossing, where hundreds of people cross from multiple directions with lights turning in synchronized waves.
